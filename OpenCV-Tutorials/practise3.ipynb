# %%
import cv2 as cv
import numpy as np
img=cv.imread("assets/chessboard.png")
img=cv.resize(img,(0,0),fx=0.5,fy=0.5)
gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
corners=cv.goodFeaturesToTrack(gray,100,0.01,10)

corners=np.int0(corners)
for corner in corners:
    x,y=corner.ravel()
    cv.circle(img,(x,y),5,(255,0,0),-1)


for i in range(len(corners)):
    for j in range(i+1,len(corners)):
        corner1=tuple(corners[i][0])
        corner2=tuple(corners[j][0])
        color=tuple(map(lambda x: int(x),np.random.randint(0,255,size=3)))
        cv.line(img,corner1,corner2,color,1)

cv.imshow('hjfj',img)
cv.waitKey(8000)
cv.destroyAllWindows()
# Out:
# /tmp/ipykernel_2528799/3026671983.py:8: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners=np.int0(corners)

# %%
import cv2 as cv
import numpy as np 
img=cv.imread("assets/soccer_practice.jpg",0)
img=cv.resize(img,(0,0),fx=0.5,fy=0.5)

template= cv.imread("assets/ball.PNG",0)
template=cv.resize(template,(0,0),fx=0.5,fy=0.5)

h,w=template.shape
methods=[cv.TM_CCOEFF,cv.TM_CCOEFF_NORMED,cv.TM_CCORR,cv.TM_CCORR_NORMED,cv.TM_SQDIFF,cv.TM_SQDIFF_NORMED]

for method in methods:
    img2=img.copy()
    result=cv.matchTemplate(img2,template,method)
    min_val,max_val,min_loc,max_loc=cv.minMaxLoc(result)
    print(min_loc,max_loc)
    if method in [cv.TM_SQDIFF,cv.TM_SQDIFF_NORMED]:
        location=min_loc
    else:
        location=max_loc
    bottom_rigth=(location[0]+w,location[1]+h)
    cv.rectangle(img2,location,bottom_rigth,255,5)
    cv.imshow('match',img2)
    cv.waitKey(0)
    cv.destroyAllWindows()
# Out:
# (56, 114) (336, 42)
# (272, 409) (336, 42)
# (538, 29) (103, 82)
# (42, 122) (336, 42)
# (336, 42) (57, 116)
# (336, 42) (0, 0)

# %%
import numpy as np 
import cv2 as cv
cap=cv.VideoCapture(0 )
fase_cascade=cv.CascadeClassifier(cv.data.haarcascades+'haarcascade_frontalface_default.xml')
eye_cascade=cv.CascadeClassifier(cv.data.haarcascades+'haarcascade_eye.xml')

while True:
    ret,frame=cap.read()
    frame=cv.rotate(frame,cv.ROTATE_90_COUNTERCLOCKWISE)
    if not ret:
      print("Failed to capture frame. Exiting...")
      break
    gray=cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
    faces=fase_cascade.detectMultiScale(gray,1.3,5)
    print(faces)
    for (x,y,w,h) in faces:
        cv.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),5)
        roi_gray=gray[y:y+w,x:x+w]
        roi_color=frame[y:y+h,x:x+w]
        eye=eye_cascade.detectMultiScale(roi_gray,1.3,5)
        for (ex,ey,ew,eh) in eye:
            cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),5)

    cv.imshow("frame",frame)
    if cv.waitKey(1)==ord('q'):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
# ()
